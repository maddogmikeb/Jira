# %% [markdown]
# <a href="https://colab.research.google.com/github/maddogmikeb/Jira/blob/master/Welcome_to_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q atlassian-python-api

# %%
from IPython.core.display import display, HTML
from atlassian import Jira
from google.colab import userdata

jira = Jira(
    url='https://brisbanecitycouncil.atlassian.net/',
    username=userdata.get('atlassian_username'),
    password=userdata.get('atlassian_apikey'),
    cloud=True
)

me = jira.myself()

display(HTML('<table><tr><td>' + me["displayName"] + '</td><td><img src="' + me["avatarUrls"]["32x32"] + '"/><td></tr></table>'))
# Out:
# <table><tr><td>Mike Burns</td><td><img src="https://avatar-management--avatars.us-west-2.prod.public.atl-paas.net/712020:d9c65884-1656-4f68-827c-32ec1a4ae098/2b84f57d-857a-4828-9cfe-4aa7b8843673/32"/><td></tr></table>

# %%
JQL = 'project = FDSEWMSR AND issuetype in (Bug, Story, Epic, Task) AND "Team[Team]" = d3706851-4fae-4b34-9a25-d4e10c5a45e4 ORDER BY Rank ASC'

data = jira.jql(JQL)

print(data)
# Out:
# {'expand': 'schema,names', 'startAt': 0, 'maxResults': 50, 'total': 208, 'issues': [{'expand': 'operations,versionedRepresentations,customfield_10294.properties,editmeta,customfield_10293.properties,changelog,customfield_10010.requestTypePractice,renderedFields', 'id': '64724', 'self': 'https://brisbanecitycouncil.atlassian.net/rest/api/2/issue/64724', 'key': 'FDSEWMSR-14819', 'fields': {'parent': {'id': '1146434', 'key': 'FDSEWMSR-17756', 'self': 'https://brisbanecitycouncil.atlassian.net/rest/api/2/issue/1146434', 'fields': {'summary': 'Manage Refunds and Reversals', 'status': {'self': 'https://brisbanecitycouncil.atlassian.net/rest/api/2/status/10174', 'description': '(Migrated on 14 Jul 2023 09:50 UTC)', 'iconUrl': 'https://brisbanecitycouncil.atlassian.net/images/icons/statuses/generic.png', 'name': 'In Solution Design', 'id': '10174', 'statusCategory': {'self': 'https://brisbanecitycouncil.atlassian.net/rest/api/2/statuscategory/4', 'id': 4, 'key': 'indeterminate', 'colorName':
# ...
